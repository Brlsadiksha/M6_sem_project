# %%
import numpy as np
import time
import glob
from datetime import datetime 
from darts.dataprocessing import Pipeline
import matplotlib.pyplot as plt
import shutil
import warnings
warnings.filterwarnings("ignore")
import logging
import pandas as pd

from tqdm import tqdm

# model
from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis, plot_hist
from darts.utils.missing_values import fill_missing_values
import torch
from darts.models import RNNModel
from darts.metrics import mape # we do not use mape, this is a problem using backtest!
from darts.metrics import rmse, mse

# mlflow
# !pip install mlflow --q
import mlflow

# %%
# data import and preprocessing
csv_files = glob.glob('/Users/dicod/semester_projects_02/Data/*.csv')
df = pd.DataFrame()

for file in csv_files:
    temp_df = pd.read_csv(file)
    df = pd.concat([df, temp_df], ignore_index=True)

df = df[['MTU (CET/CEST)','Day-ahead Price [EUR/MWh]']]
df = df.rename(columns={'MTU (CET/CEST)': 'date', 'Day-ahead Price [EUR/MWh]': 'Price'})

df['date'] = df['date'].apply(lambda x: x[0:16])
df = df[df['Price'] != '-']
median_price = df['Price'].median()
df['Price'].fillna(median_price, inplace=True)  
df_no_duplicates = df.drop_duplicates(subset='date')
df_no_duplicates.to_csv('df_clean.csv')

# %%
df = pd.read_csv('df_clean.csv')

# %%
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)
ts = time_series

# %%
# model build
# Create training and validation sets:
train, test = ts.split_after(pd.Timestamp("01.01.2023 01:00"))

# Normalize the time series (note: we avoid fitting the transformer on the validation set)
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)

# %%
# dart recommendation, but I think we will use random methold.
train.plot(label="training")
test.plot(label="test")

# %%
train_transformed.plot()
test_transformed.plot()

# %% [markdown]
# # Covariates Effect

# %% [markdown]
# note that: https://unit8co.github.io/darts/examples/04-RNN-examples.html#Recurrent-Models

# %% [markdown]
# why we used scaler: because we will use other data like a wind, solar, temperature, so we did.

# %%
# create day and time covariate series_basic one (I think our data is important day and hour relationship.)

hour_series = datetime_attribute_timeseries(
    pd.date_range(start=ts.start_time(), freq=ts.freq_str, periods=26304),
    attribute="hour",
    one_hot=False)
day_series = datetime_attribute_timeseries(
    pd.date_range(start=ts.start_time(), freq=ts.freq_str, periods=26304),
    attribute="day",
    one_hot=False)
month_series = datetime_attribute_timeseries(
    pd.date_range(start=ts.start_time(), freq=ts.freq_str, periods=26304),
    attribute="month",
    one_hot=False)
year_series = datetime_attribute_timeseries(
    pd.date_range(start=ts.start_time(), freq=ts.freq_str, periods=26304),
    attribute="year",
    one_hot=False)
weekday_series = datetime_attribute_timeseries(
    pd.date_range(start=ts.start_time(), freq=ts.freq_str, periods=26304),
    attribute="dayofweek",
    one_hot=False)
weekofyear_series = datetime_attribute_timeseries(
    pd.date_range(start=ts.start_time(), freq=ts.freq_str, periods=26304),
    attribute="weekofyear",
    one_hot=False)

# %%
# series_transform
hour_trasform = Scaler().fit_transform(hour_series)
day_transform = Scaler().fit_transform(day_series)
month_transform = Scaler().fit_transform(month_series)
year_transform = Scaler().fit_transform(year_series)
weekday_transform = Scaler().fit_transform(weekday_series)
weekofyear_transform = Scaler().fit_transform(weekofyear_series)

# %%
# we make 3 kinds of covariates : day and hour, dayofweek and dayofyear, all

cov_day_hour = day_transform.stack(hour_series)
cov_dayofweek_dayofyear = weekday_transform.stack(weekofyear_transform)
cov_all = hour_trasform.stack(day_transform).stack(month_transform).stack(year_transform).stack(weekday_transform).stack(weekofyear_transform)

# %%
cov_all
# Out:
# <TimeSeries (DataArray) (time: 26304, component: 6, sample: 1)>
# array([[[0.        ],
#         [0.        ],
#         [0.        ],
#         [0.        ],
#         [0.33333333],
#         [0.        ]],
#
#        [[0.04347826],
#         [0.        ],
#         [0.        ],
#         [0.        ],
#         [0.33333333],
#         [0.        ]],
#
#        [[0.08695652],
#         [0.        ],
#         [0.        ],
#         [0.        ],
#         [0.33333333],
#         [0.        ]],
# ...
#        [[0.91304348],
#         [1.        ],
#         [1.        ],
#         [1.        ],
#         [0.83333333],
#         [0.98076923]],
#
#        [[0.95652174],
#         [1.        ],
#         [1.        ],
#         [1.        ],
#         [0.83333333],
#         [0.98076923]],
#
#        [[1.        ],
#         [1.        ],
#         [1.        ],
#         [1.        ],
#         [0.83333333],
#         [0.98076923]]])
# Coordinates:
#   * time       (time) datetime64[ns] 2020-01-01 ... 2022-12-31T23:00:00
#   * component  (component) object 'hour' 'day' ... 'dayofweek' 'weekofyear'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
plt.figure(figsize=(15,5))
cov_all.plot()

# %%
plt.figure(figsize=(15,5))
cov_all[-800:].plot()

# %%
scaled_day_series = Scaler().fit_transform(day_series)
hour_series = datetime_attribute_timeseries(scaled_day_series, attribute="hour", one_hot=True)

# %%
covariates_day_hour = scaled_day_series.stack(hour_series)

cov_train, cov_test = covariates_day_hour.split_after(pd.Timestamp('01.01.2022 01:00'))

# %%
year_series = datetime_attribute_timeseries(
    pd.date_range(start=ts.start_time(), freq=ts.freq_str, periods=26304),
    attribute="day",
    one_hot=False)
year_series = Scaler().fit_transform(year_series)
month_series = datetime_attribute_timeseries(
    year_series, attribute="month", one_hot=True
)
covariates_ym = year_series.stack(month_series)
cov_train, cov_val = covariates_ym.split_after(pd.Timestamp('01.01.2022 01:00'))

# %%
print("Train size : ", len(train))
print("Test size  : ", len(test))
print()
# Out:
# Train size :  26306
# Test size  :  8134

# %%
# I will change something  test!!

# %% [markdown]
# # Run

# %% [markdown]
# run 0521

# %% [markdown]
# * hidden_dim : Size for feature maps for each hidden RNN layer
# * n_rnn_layers : Number of layers in the RNN module.
# * loss_fn : which function we will use loss_fn
# * torch_metrics :

# %%
# Start an MLflow run_with cov_all
from sklearn.metrics import r2_score

mlflow.pytorch.autolog()
mlflow.set_experiment('EL_Price_experiments')


# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2023 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)


with mlflow.start_run(run_name="run_10", nested=True):
    my_model = RNNModel(
    model="LSTM",
    hidden_dim=5, #5, 10, 15
    dropout=0,
    batch_size=72, 
    n_epochs=30,
    optimizer_kwargs={"lr": 1e-3},
    model_name="ELPrice_RNN",
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    input_chunk_length=72,
    force_reset=True,
    save_checkpoints=True,
)

# Train a RNN model
    my_model.fit(
    train,
    future_covariates=cov_all,
    val_series=test,
    val_future_covariates=cov_all,
    verbose=False)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=30` reached.
# 2023/05/21 12:33:38 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during pytorch autologging: 'LightningDoublePrecisionModule' object has no attribute 'example_input_array'

# %%
rnn0_rmse = rmse(train, test)

mlflow.log_metric("RMSE", rnn0_rmse)

# %%
pred_series = my_model.predict(len(test), future_covariates=cov_all)
plt.figure(figsize=(8, 5))
ts.plot(label="actual")
pred_series.plot(label="forecast")
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
# Register the model in the MLflow registry
run_id_active = mlflow.active_run().info.run_id
model_uri = "runs:/" + run_id_active + "/EL_Price_experiments"
model_version = mlflow.register_model(model_uri, "model_rnn_pred")
# Out:
# Successfully registered model 'model_rnn_pred'.
# 2023/05/21 12:38:55 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: model_rnn_pred, version 1
# Created version '1' of model 'model_rnn_pred'.

# %%
mlflow.end_run()

# %% [markdown]
# run

# %%
# Start an MLflow run_with cov_all
from sklearn.metrics import r2_score

mlflow.pytorch.autolog()
mlflow.set_experiment('EL_Price_experiments')


# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)


with mlflow.start_run(run_name="run_11", nested=True):
    my_model = RNNModel(
    model="LSTM",
    hidden_dim=10, #5, 10, 15
    dropout=0,
    batch_size=200, 
    n_epochs=50,
    optimizer_kwargs={"lr": 1e-3},
    model_name="ELPrice_RNN",
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    input_chunk_length=72,
    force_reset=True,
    save_checkpoints=True,
)

# Train a RNN model
    my_model.fit(
    train_transformed,
    future_covariates=cov_all,
    val_series=test_transformed,
    val_future_covariates=cov_all,
    verbose=False)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=50` reached.
# 2023/05/21 12:49:51 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during pytorch autologging: 'LightningDoublePrecisionModule' object has no attribute 'example_input_array'

# %%
rnn0_rmse = rmse(train_transformed, test_transformed)

mlflow.log_metric("RMSE", rnn0_rmse)

# %%
pred_series = my_model.predict(len(test), future_covariates=cov_all)
plt.figure(figsize=(8, 5))
ts.plot(label="actual")
pred_series.plot(label="forecast")
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
# Register the model in the MLflow registry
run_id_active = mlflow.active_run().info.run_id
model_uri = "runs:/" + run_id_active + "/EL_Price_experiments"
model_version = mlflow.register_model(model_uri, "model_rnn_pred")
# Out:
# Registered model 'model_rnn_pred' already exists. Creating a new version of this model...
# 2023/05/21 12:49:53 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: model_rnn_pred, version 2
# Created version '2' of model 'model_rnn_pred'.

# %%
mlflow.end_run()

# %%
# Start an MLflow run_with cov_all
from sklearn.metrics import r2_score

mlflow.pytorch.autolog()
mlflow.set_experiment('EL_Price_experiments')


# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)


with mlflow.start_run(run_name="run_12", nested=True):
    my_model = RNNModel(
    model="LSTM",
    hidden_dim=15, #5, 10, 15
    dropout=0,
    batch_size=200, 
    n_epochs=100,
    optimizer_kwargs={"lr": 1e-3},
    model_name="ELPrice_RNN",
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    input_chunk_length=72,
    force_reset=True,
    save_checkpoints=True,
)

# Train a RNN model
    my_model.fit(
    train_transformed,
    future_covariates=cov_all,
    val_series=test_transformed,
    val_future_covariates=cov_all,
    verbose=False)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=100` reached.
# 2023/05/21 13:12:57 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during pytorch autologging: 'LightningDoublePrecisionModule' object has no attribute 'example_input_array'

# %%
rnn0_rmse = rmse(train_transformed, test_transformed)

mlflow.log_metric("RMSE", rnn0_rmse)

# %%
pred_series = my_model.predict(len(test), future_covariates=cov_all)
plt.figure(figsize=(8, 5))
ts.plot(label="actual")
pred_series.plot(label="forecast")
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
# Register the model in the MLflow registry
run_id_active = mlflow.active_run().info.run_id
model_uri = "runs:/" + run_id_active + "/EL_Price_experiments"
model_version = mlflow.register_model(model_uri, "model_rnn_pred")
# Out:
# Registered model 'model_rnn_pred' already exists. Creating a new version of this model...
# 2023/05/21 13:12:59 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: model_rnn_pred, version 3
# Created version '3' of model 'model_rnn_pred'.

# %%
mlflow.end_run()

# %%
# Start an MLflow run_with cov_all
from sklearn.metrics import r2_score

mlflow.pytorch.autolog()
mlflow.set_experiment('EL_Price_experiments')


# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)


with mlflow.start_run(run_name="run_13", nested=True):
    my_model = RNNModel(
    model="LSTM",
    hidden_dim=15, #5, 10, 15
    dropout=0,
    batch_size=500, 
    n_epochs=100,
    optimizer_kwargs={"lr": 1e-3},
    model_name="ELPrice_RNN",
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    input_chunk_length=72,
    force_reset=True,
    save_checkpoints=True,
)

# Train a RNN model
    my_model.fit(
    train_transformed,
    future_covariates=cov_all,
    val_series=test_transformed,
    val_future_covariates=cov_all,
    verbose=False)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=100` reached.
# 2023/05/21 13:32:03 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during pytorch autologging: 'LightningDoublePrecisionModule' object has no attribute 'example_input_array'

# %%
rnn0_rmse = rmse(train_transformed, test_transformed)

mlflow.log_metric("RMSE", rnn0_rmse)

# %%
pred_series = my_model.predict(len(test), future_covariates=cov_all)
plt.figure(figsize=(8, 5))
ts.plot(label="actual")
pred_series.plot(label="forecast")
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
# Register the model in the MLflow registry
run_id_active = mlflow.active_run().info.run_id
model_uri = "runs:/" + run_id_active + "/EL_Price_experiments"
model_version = mlflow.register_model(model_uri, "model_rnn_pred")
# Out:
# Registered model 'model_rnn_pred' already exists. Creating a new version of this model...
# 2023/05/21 13:32:05 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: model_rnn_pred, version 4
# Created version '4' of model 'model_rnn_pred'.

# %%
mlflow.end_run()

# %%
# Start an MLflow run_with cov_all
from sklearn.metrics import r2_score

mlflow.pytorch.autolog()
mlflow.set_experiment('EL_Price_experiments')


# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)


with mlflow.start_run(run_name="run_6", nested=True):
    my_model = RNNModel(
    model="LSTM",
    hidden_dim=20, #
    dropout=0,
    batch_size=100, 
    n_epochs=100, # try it: 30, 50, 100
    optimizer_kwargs={"lr": 1e-3},
    model_name="ELPrice_RNN",
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    input_chunk_length=72,
    force_reset=True,
    save_checkpoints=True,
)

# Train a RNN model
    my_model.fit(
    train_transformed,
    future_covariates=cov_all,
    val_series=test_transformed,
    val_future_covariates=cov_all,
    verbose=False,
)
    
def eval_model(model):
    pred_series = model.predict(n=8761, future_covariates=cov_all)
    plt.figure(figsize=(8, 5))
    series_transformed.plot(label="actual")
    pred_series.plot(label="forecast")

    # Reshape or slice the arrays to ensure compatibility
    test_transformed_reshaped = test_transformed.ravel()  # Flatten the array if needed
    pred_series_reshaped = pred_series.ravel()  # Flatten the array if needed

    r2 = r2_score(test_transformed_reshaped, pred_series_reshaped)
    plt.title("R-squared: {:.2f}".format(r2))
    plt.legend()

    rmse = np.sqrt(mean_squared_error(test_transformed_reshaped, pred_series_reshaped))
    mlflow.log_metric("rmse", rmse)
    eval_model(my_model)
    
mlflow.end_run()
# Out:
# 2023/05/16 19:08:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2023/05/16 19:08:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2023/05/16 19:08:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for pytorch_lightning.
# 2023/05/16 19:08:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# 2023/05/16 19:08:35 INFO mlflow.tracking.fluent: Autologging successfully enabled for lightgbm.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=100` reached.
# 2023/05/16 19:42:54 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during pytorch autologging: 'LightningDoublePrecisionModule' object has no attribute 'example_input_array'

# %%
# Start an MLflow with cov_dayofweek_dayofyear

mlflow.autolog()

mlflow.set_experiment('EL_Price_experiments')


# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)

with mlflow.start_run(run_name="run_7", nested=True):
    my_model = RNNModel(
    model="LSTM",
    hidden_dim=10, #
    dropout=0,
    batch_size=24, 
    n_epochs=100, # try it: 30, 50, 100
    optimizer_kwargs={"lr": 1e-3},
    model_name="ELPrice_RNN",
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    input_chunk_length=72,
    force_reset=True,
    save_checkpoints=True,
)

# Train a RNN model
    my_model.fit(
    train_transformed,
    future_covariates=cov_all,
    val_series=test_transformed,
    val_future_covariates=cov_all,
    verbose=False,
)
    
    def eval_model(model):
        pred_series = model.predict(n=8758, future_covariates=cov_all)
        plt.figure(figsize=(8, 5))
        series_transformed.plot(label="actual")
        pred_series.plot(label="forecast")
        plt.title("MAPE: {:.2f}%".format(mape(pred_series, test_transformed)))
        plt.legend()


    eval_model(my_model)
# Out:
# 2023/05/16 07:16:52 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2023/05/16 07:16:52 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2023/05/16 07:16:52 INFO mlflow.tracking.fluent: Autologging successfully enabled for pytorch_lightning.
# 2023/05/16 07:16:52 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# 2023/05/16 07:16:52 INFO mlflow.tracking.fluent: Autologging successfully enabled for lightgbm.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=100` reached.
# 2023/05/16 07:38:30 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during pytorch autologging: 'LightningDoublePrecisionModule' object has no attribute 'example_input_array'
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
# Start an MLflow run_with cov_all

mlflow.autolog()

mlflow.set_experiment('EL_Price_experiments')


# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)

with mlflow.start_run(run_name="run_6", nested=True):
    my_model = RNNModel(
    model="LSTM",
    hidden_dim=30, #
    dropout=0,
    batch_size=48, 
    n_epochs=100, # try it: 30, 50, 100
    optimizer_kwargs={"lr": 1e-3},
    model_name="ELPrice_RNN",
    log_tensorboard=True,
    random_state=42,
    training_length=20,
    input_chunk_length=72,
    force_reset=True,
    save_checkpoints=True,
)

# Train a RNN model
    my_model.fit(
    train_transformed,
    future_covariates=cov_all,
    val_series=test_transformed,
    val_future_covariates=cov_all,
    verbose=False,
)
    
    def eval_model(model):
    pred_series = model.predict(n=8761, future_covariates=cov_all)
    plt.figure(figsize=(8, 5))
    series_transformed.plot(label="actual")
    pred_series.plot(label="forecast")

    # Reshape or slice the arrays to ensure compatibility
    test_transformed_reshaped = test_transformed.ravel()  # Flatten the array if needed
    pred_series_reshaped = pred_series.ravel()  # Flatten the array if needed

    r2 = r2_score(test_transformed_reshaped, pred_series_reshaped)
    plt.title("R-squared: {:.2f}".format(r2))
    plt.legend()

    rmse = np.sqrt(mean_squared_error(test_transformed_reshaped, pred_series_reshaped))
    mlflow.log_metric("rmse", rmse)
    eval_model(my_model)
# Out:
# 2023/05/16 07:38:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2023/05/16 07:38:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2023/05/16 07:38:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for pytorch_lightning.
# 2023/05/16 07:38:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# 2023/05/16 07:38:32 INFO mlflow.tracking.fluent: Autologging successfully enabled for lightgbm.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=100` reached.
# 2023/05/16 08:14:30 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during pytorch autologging: 'LightningDoublePrecisionModule' object has no attribute 'example_input_array'
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 62
#      56     mlflow.log_metric("rmse", rmse)
#      57     mlflow.log_metric("R2",r2)
# ---> 62 eval_model(my_model)
#
# Cell In[35], line 50, in eval_model(model)
#      48 series_transformed.plot(label="actual")
#      49 pred_series.plot(label="forecast")
# ---> 50 r2 = r2_score(test_transformed, pred_series)
#      51 plt.title("R-squared: {:.2f}".format(r2))
#      53 plt.legend()
#
# File ~\anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:554, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     552     patch_function.call(call_original, *args, **kwargs)
#     553 else:
# --> 554     patch_function(call_original, *args, **kwargs)
#     556 session.state = "succeeded"
#     558 try_log_autologging_event(
#     559     AutologgingEventLogger.get_logger().log_patch_function_success,
#     560     session,
#    (...)
#     564     kwargs,
#     565 )
#
# File ~\anaconda3\lib\site-packages\mlflow\sklearn\__init__.py:1624, in _autolog.<locals>.patched_metric_api(original, *args, **kwargs)
#    1620 if _AUTOLOGGING_METRICS_MANAGER.should_log_post_training_metrics():
#    1621     # one metric api may call another metric api,
#    1622     # to avoid this, call disable_log_post_training_metrics to avoid nested patch
#    1623     with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> 1624         metric = original(*args, **kwargs)
#    1626     if _AUTOLOGGING_METRICS_MANAGER.is_metric_value_loggable(metric):
#    1627         metric_name = original.__name__
#
# File ~\anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:535, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     532         original_result = original(*_og_args, **_og_kwargs)
#     533         return original_result
# --> 535 return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File ~\anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:470, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     461 try:
#     462     try_log_autologging_event(
#     463         AutologgingEventLogger.get_logger().log_original_function_start,
#     464         session,
#    (...)
#     468         og_kwargs,
#     469     )
# --> 470     original_fn_result = original_fn(*og_args, **og_kwargs)
#     472     try_log_autologging_event(
#     473         AutologgingEventLogger.get_logger().log_original_function_success,
#     474         session,
#    (...)
#     478         og_kwargs,
#     479     )
#     480     return original_fn_result
#
# File ~\anaconda3\lib\site-packages\mlflow\utils\autologging_utils\safety.py:532, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     524 # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     525 # during original function execution, even if silent mode is enabled
#     526 # (`silent=True`), since these warnings originate from the ML framework
#     527 # or one of its dependencies and are likely relevant to the caller
#     528 with set_non_mlflow_warnings_behavior_for_current_thread(
#     529     disable_warnings=False,
#     530     reroute_warnings=False,
#     531 ):
# --> 532     original_result = original(*_og_args, **_og_kwargs)
#     533     return original_result
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:911, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#     784 def r2_score(
#     785     y_true,
#     786     y_pred,
#    (...)
#     790     force_finite=True,
#     791 ):
#     792     """:math:`R^2` (coefficient of determination) regression score function.
#     793
#     794     Best possible score is 1.0 and it can be negative (because the
#    (...)
#     909     -inf
#     910     """
# --> 911     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     912         y_true, y_pred, multioutput
#     913     )
#     914     check_consistent_length(y_true, y_pred, sample_weight)
#     916     if _num_samples(y_pred) < 2:
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:101, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      67 """Check that y_true and y_pred belong to the same regression task.
#      68
#      69 Parameters
#    (...)
#      98     correct keyword.
#      99 """
#     100 check_consistent_length(y_true, y_pred)
# --> 101 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     104 if y_true.ndim == 1:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:915, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     910     raise ValueError(
#     911         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     912         "Convert your data to numeric values explicitly instead."
#     913     )
#     914 if not allow_nd and array.ndim >= 3:
# --> 915     raise ValueError(
#     916         "Found array with dim %d. %s expected <= 2."
#     917         % (array.ndim, estimator_name)
#     918     )
#     920 if force_all_finite:
#     921     _assert_all_finite(
#     922         array,
#     923         input_name=input_name,
#     924         estimator_name=estimator_name,
#     925         allow_nan=force_all_finite == "allow-nan",
#     926     )
#
# ValueError: Found array with dim 32. None expected <= 2.

# %% [markdown]
# ### Backtest (Evaluation)

# %%
# backtest
    backtest_series = my_model.historical_forecasts(
    series_transformed,
    future_covariates=covariates,
    start=pd.Timestamp("01.01.2022 01:00"),
    forecast_horizon=12,
    retrain=False,
    verbose=True,
)

# %%
plt.figure(figsize=(8, 5))
series_transformed.plot(label="actual")
backtest_series.plot(label="backtest")
plt.legend()
plt.title("Backtest, starting Jan 2022, 12-months horizon")
r2 = r2_score(transformer.inverse_transform(series_transformed),
            transformer.inverse_transform(backtest_series))

# %%
def eval_model(model):
    pred_series = model.predict(n=8750, future_covariates=covariates)
    plt.figure(figsize=(8, 5))
    series_transformed.plot(label="actual")
    pred_series.plot(label="forecast")
    plt.title("RMSE: {:.2f}%".format(rmse(pred_series, test_transformed)))
    plt.legend()


eval_model(my_model)

# %%
plt.figure(figsize=(8, 5))
series_transformed.plot(label="actual")
backtest_series.plot(label="backtest")
plt.legend()
plt.title("Backtest, starting Jan 2022, 12-months horizon")
print(
    "RMSE: {:.2f}%".format(
        rmse(
            transformer.inverse_transform(series_transformed),
            transformer.inverse_transform(backtest_series),
        )
    )
)

# %% [markdown]
# --------------------------------------------------ignore the below code------------------------------------------------------

# %%
if __name__ == '__main__':
    model, accuracy = my_model()
    print(f"Model trained with accuracy: {accuracy}")
    mlflow.log_metric("accuracy", accuracy)
    mlflow.dart.log_model(my_model, "model", registered_model_name="ELPrice_RNN")
    mlflow.dart.save_model(my_model, "ELPrice_RNN")

# %%
# Register the model in the MLflow registry
run_id_active = mlflow.active_run().info.run_id
model_uri = "runs:/" + run_id_active + "/test_0"
model_version = mlflow.register_model(model_uri, "ELPrice_RNN")

# %%
# Log metrics
    y_pred = my_model.predict(train_transformed)
    mse = mean_squared_error(test_transformed, y_pred)
    rmse = math.sqrt(mse)
    mlflow.log_metric("mse", mse)
    mlflow.log_metric("rmse", rmse)

# %%
my_model.fit(
    train_transformed,
    future_covariates=covariates,
    val_series=test_transformed,
    val_future_covariates=covariates,
    verbose=True,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | rnn           | LSTM             | 2.9 K
# 4 | V             | Linear           | 21
# ---------------------------------------------------
# 2.9 K     Trainable params
# 0         Non-trainable params
# 2.9 K     Total params
# 0.012     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# RNNModel(model=LSTM, hidden_dim=20, n_rnn_layers=1, dropout=0, training_length=20, batch_size=16, n_epochs=10, optimizer_kwargs={'lr': 0.001}, model_name=ELPrice_RNN, log_tensorboard=True, random_state=42, input_chunk_length=72, force_reset=True, save_checkpoints=True)

# %%
model_nbeats.fit(train, val_series=test, verbose=True)

# %%
mlflow.pytorch.autolog()

# %%
from darts.metrics import rmse

# %%
def eval_model(model):
    pred_series = model.predict(n=8700, future_covariates=covariates)
    plt.figure(figsize=(8, 5))
    series_transformed.plot(label="actual")
    pred_series.plot(label="forecast")
    plt.title("RMSE: {:.2f}%".format(rmse(pred_series, test_transformed)))
    plt.legend()


eval_model(my_model)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]

# %%
# Start an MLflow run
with mlflow.start_run(run_name="test_0", nested=True)
    # Log parameters
    model_nbeats = NBEATSModel(
    input_chunk_length=30,
    output_chunk_length=7,
    generic_architecture=True,
    num_stacks=10,
    num_blocks=1,
    num_layers=4,
    layer_widths=512,
    n_epochs=10,
    nr_epochs_val_period=1,
    batch_size=800,
    model_name="nbeats_run",
)

# Log parameters
model_nbeats = NBEATSModel(
    input_chunk_length=30,
    output_chunk_length=7,
    generic_architecture=True,
    num_stacks=10,
    num_blocks=1,
    num_layers=4,
    layer_widths=512,
    n_epochs=10,
    nr_epochs_val_period=1,
    batch_size=800,
    model_name="nbeats_run",
)

# %%
# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)

# Train a RNN model
model = RNNModel(input_chunk_length=72)
model.fit(train_transformed)

class RNNModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(RNNModel, self).__init__()
        self.hidden_dim = hidden_dim
        self.rnn = nn.RNN(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(1, x.size(0), self.hidden_dim).to(device)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])
        return out

def train_model(learning_rate=0.001):
    # Set the learning rate of the optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    # Train the model
    # ...
    
if __name__ == '__main__':
    model, accuracy = train_model(learning_rate=0.0001)
    print(f"Model trained with accuracy: {accuracy}")
    mlflow.log_metric("accuracy", accuracy)
    mlflow.sklearn.log_model(model, "model")
    mlflow.sklearn.log_model(model, "model", registered_model_name="rnn_model")
    mlflow.sklearn.save_model(model, "rnn_model")

    # Launch MLflow UI
    import os
    os.system("mlflow ui")

# %%
# Load data
data = pd.read_csv('df_clean.csv')
time_series = TimeSeries.from_dataframe(df, time_col='date', value_cols = 'Price', fill_missing_dates=True, freq=None)

# Split data and scaler
train, test = ts.split_after(pd.Timestamp("01.01.2022 01:00"))
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
test_transformed = transformer.transform(test)
series_transformed = transformer.transform(ts)

# Train a RNN model
model = RNNModel(input_chunk_length=72)
model.fit(train_transformed)

# Log metrics
y_pred = model.predict(train_transformed)
mse = mean_squared_error(test_transformed, y_pred)
rmse = math.sqrt(mse)
mlflow.log_metric("mse", mse)
    
if __name__ == '__main__':
    model, accuracy = train_model()
    print(f"Model trained with accuracy: {accuracy}")
    mlflow.log_metric("accuracy", accuracy)
    mlflow.dart.log_model(model, "model")
    mlflow.dart.log_model(model, "model", registered_model_name="rnn_model")
    mlflow.dart.save_model(model, "rnn_model")
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | criterion     | MSELoss          | 0
# 1 | train_metrics | MetricCollection | 0
# 2 | val_metrics   | MetricCollection | 0
# 3 | rnn           | RNN              | 700
# 4 | V             | Linear           | 26
# ---------------------------------------------------
# 726       Trainable params
# 0         Non-trainable params
# 726       Total params
# 0.003     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 17
#      14 model.fit(train_transformed)
#      16 # Log metrics
# ---> 17 y_pred = model.predict(train_transformed)
#      18 mse = mean_squared_error(test_transformed, y_pred)
#      19 rmse = math.sqrt(mse)
#
# File ~\anaconda3\lib\site-packages\darts\utils\torch.py:112, in random_method.<locals>.decorator(self, *args, **kwargs)
#     110 with fork_rng():
#     111     manual_seed(self._random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# --> 112     return decorated(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:1317, in TorchForecastingModel.predict(self, n, series, past_covariates, future_covariates, trainer, batch_size, verbose, n_jobs, roll_size, num_samples, num_loader_workers, mc_dropout)
#    1308 super().predict(n, series, past_covariates, future_covariates)
#    1310 dataset = self._build_inference_dataset(
#    1311     target=series,
#    1312     n=n,
#    1313     past_covariates=past_covariates,
#    1314     future_covariates=future_covariates,
#    1315 )
# -> 1317 predictions = self.predict_from_dataset(
#    1318     n,
#    1319     dataset,
#    1320     trainer=trainer,
#    1321     verbose=verbose,
#    1322     batch_size=batch_size,
#    1323     n_jobs=n_jobs,
#    1324     roll_size=roll_size,
#    1325     num_samples=num_samples,
#    1326     num_loader_workers=num_loader_workers,
#    1327     mc_dropout=mc_dropout,
#    1328 )
#    1330 return predictions[0] if called_with_single_series else predictions
#
# File ~\anaconda3\lib\site-packages\darts\utils\torch.py:112, in random_method.<locals>.decorator(self, *args, **kwargs)
#     110 with fork_rng():
#     111     manual_seed(self._random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# --> 112     return decorated(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:1447, in TorchForecastingModel.predict_from_dataset(self, n, input_series_dataset, trainer, batch_size, verbose, n_jobs, roll_size, num_samples, num_loader_workers, mc_dropout)
#    1442 self.trainer = self._setup_trainer(
#    1443     trainer=trainer, model=self.model, verbose=verbose, epochs=self.n_epochs
#    1444 )
#    1446 # prediction output comes as nested list: list of predicted `TimeSeries` for each batch.
# -> 1447 predictions = self.trainer.predict(self.model, pred_loader)
#    1448 # flatten and return
#    1449 return [ts for batch in predictions for ts in batch]
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\trainer\trainer.py:805, in Trainer.predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     803     model = _maybe_unwrap_optimized(model)
#     804     self.strategy._lightning_module = model
# --> 805 return call._call_and_handle_interrupt(
#     806     self, self._predict_impl, model, dataloaders, datamodule, return_predictions, ckpt_path
#     807 )
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\trainer\call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#      43     else:
# ---> 44         return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\trainer\trainer.py:847, in Trainer._predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     842 self._data_connector.attach_data(model, predict_dataloaders=dataloaders, datamodule=datamodule)
#     844 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     845     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     846 )
# --> 847 results = self._run(model, ckpt_path=ckpt_path)
#     849 assert self.state.stopped
#     850 self.predicting = False
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\trainer\trainer.py:935, in Trainer._run(self, model, ckpt_path)
#     930 self._signal_connector.register_signal_handlers()
#     932 # ----------------------------
#     933 # RUN THE TRAINER
#     934 # ----------------------------
# --> 935 results = self._run_stage()
#     937 # ----------------------------
#     938 # POST-Training CLEAN UP
#     939 # ----------------------------
#     940 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\trainer\trainer.py:973, in Trainer._run_stage(self)
#     971     return self._evaluation_loop.run()
#     972 if self.predicting:
# --> 973     return self.predict_loop.run()
#     974 if self.training:
#     975     with isolate_rng():
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\loops\utilities.py:177, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     175     context_manager = torch.no_grad
#     176 with context_manager():
# --> 177     return loop_run(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\loops\prediction_loop.py:112, in _PredictionLoop.run(self)
#     110     batch, batch_idx, dataloader_idx = next(data_fetcher)
#     111     self.batch_progress.is_last_batch = data_fetcher.done
# --> 112     self._predict_step(batch, batch_idx, dataloader_idx)
#     113 except StopIteration:
#     114     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     115     break
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\loops\prediction_loop.py:228, in _PredictionLoop._predict_step(self, batch, batch_idx, dataloader_idx)
#     225 self.batch_progress.increment_started()
#     227 # configure step_kwargs
# --> 228 predictions = call._call_strategy_hook(trainer, "predict_step", *step_kwargs.values())
#     230 self.batch_progress.increment_processed()
#     232 if predictions is None:
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\trainer\call.py:288, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     285     return
#     287 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 288     output = fn(*args, **kwargs)
#     290 # restore current_fx when nested context
#     291 pl_module._current_fx_name = prev_fx_name
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\strategies\strategy.py:396, in Strategy.predict_step(self, *args, **kwargs)
#     394 with self.precision_plugin.predict_step_context():
#     395     assert isinstance(self.model, PredictStep)
# --> 396     return self.model.predict_step(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pytorch_lightning\plugins\precision\double.py:60, in LightningDoublePrecisionModule.predict_step(self, *args, **kwargs)
#      59 def predict_step(self, *args: Any, **kwargs: Any) -> Any:
# ---> 60     return self.module.predict_step(
#      61         *LightningDoublePrecisionModule._move_float_tensors_to_double(args),
#      62         **LightningDoublePrecisionModule._move_float_tensors_to_double(kwargs),
#      63     )
#
# File ~\anaconda3\lib\site-packages\darts\models\forecasting\pl_forecasting_module.py:228, in PLForecastingModule.predict_step(self, batch, batch_idx, dataloader_idx)
#     222 input_data_tuple_samples = self._sample_tiling(
#     223     input_data_tuple, batch_sample_size
#     224 )
#     226 # get predictions for 1 whole batch (can include predictions of multiple series
#     227 # and for multiple samples if a probabilistic forecast is produced)
# --> 228 batch_prediction = self._get_batch_prediction(
#     229     self.pred_n, input_data_tuple_samples, self.pred_roll_size
#     230 )
#     232 # reshape from 3d tensor (num_series x batch_sample_size, ...)
#     233 # into 4d tensor (batch_sample_size, num_series, ...), where dim 0 represents the samples
#     234 out_shape = batch_prediction.shape
#
# File ~\anaconda3\lib\site-packages\darts\models\forecasting\rnn_model.py:166, in _RNNModule._get_batch_prediction(self, n, input_batch, roll_size)
#     163 batch_prediction.append(out[:, -1:, :])
#     164 prediction_length = 1
# --> 166 while prediction_length < n:
#     167
#     168     # create new input to model from last prediction and current covariates, if available
#     169     new_input = (
#     170         torch.cat(
#     171             [
#    (...)
#     178         else out[:, -1:, :]
#     179     )
#     181     # feed new input to model, including the last hidden state from the previous iteration
#
# File ~\anaconda3\lib\site-packages\xarray\core\common.py:147, in AbstractArray.__bool__(self)
#     146 def __bool__(self: Any) -> bool:
# --> 147     return bool(self.values)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# backtest (later do that, if I find out theh best model!)
''''backtest_series = my_model.historical_forecasts(
    series_transformed,
    future_covariates=covariates,
    start=pd.Timestamp("01.01.2022 01:00"),
    forecast_horizon=12,
    retrain=False,
    verbose=True,
)

# %%
model = my_model

# %%
# connect mlflow
# !pip install mlflow --q
import mlflow

# %%
mlflow.set_experiment('EL_Price_experiments')

# Start an MLflow run
mlflow.start_run(run_name="run_1", nested=True)

# Log parameters
mlflow.log_param("alpha", 0.5)
# Out:
# 0.5

# %%
# Register the model in the MLflow registry
run_id_active = mlflow.active_run().info.run_id
model_uri = "runs:/" + run_id_active + "/model"
model_version = mlflow.register_model(model_uri, "MyModel")
# Out:
# Registered model 'MyModel' already exists. Creating a new version of this model...
# 2023/05/12 15:18:37 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: MyModel, version 2
# Created version '2' of model 'MyModel'.

# %%
# !mlflow experiments search -v all
# Out:
# Experiment Id       Name                  Artifact Location
# ------------------  --------------------  ---------------------------------------------------------------------
# 0                   Default               file:///C:/Users/dicod/semester_projects_02/mlruns/0
# 110241433576543131  EL_Price_experiments  file:///C:/Users/dicod/semester_projects_02/mlruns/110241433576543131

# %%
import mlflow

# Set the name of the experiment
experiment_name = "EL_Price_experiments"

# Get the experiment ID for the experiment with the specified name
experiment_id = mlflow.get_experiment_by_name(experiment_name).experiment_id

# Search for runs associated with the experiment ID
runs = mlflow.search_runs(experiment_ids=experiment_id)

# # Print information about each run
# for run in runs:
#     print(f"Run {run.info.run_id} completed at {run.info.end_time} with status {run.info.status}")

# %%
runs
# Out:
#                              run_id       experiment_id   status  \
# 0  62c6f46d7bf34358bccabcf5733cdc60  110241433576543131  RUNNING
# 1  6e0d24d6f1bf4567bfd09820c2c287ab  110241433576543131  RUNNING
# 2  a535cabca57844349fce25846103e5df  110241433576543131  RUNNING
# 3  05e2b6ae6f2041f2b31defb3ec7260a5  110241433576543131  RUNNING
# 4  9c80ada3cde44b13b9d011309bb6cb37  110241433576543131  RUNNING
#
#                                         artifact_uri  \
# 0  file:///C:/Users/dicod/semester_projects_02/ml...
# 1  file:///C:/Users/dicod/semester_projects_02/ml...
# 2  file:///C:/Users/dicod/semester_projects_02/ml...
# 3  file:///C:/Users/dicod/semester_projects_02/ml...
# 4  file:///C:/Users/dicod/semester_projects_02/ml...
#
#                         start_time end_time params.alpha tags.mlflow.user  \
# 0 2023-05-12 13:18:20.388000+00:00     None          0.5            dicod
# 1 2023-05-12 12:20:45.687000+00:00     None          0.5            dicod
# 2 2023-05-12 12:09:08.740000+00:00     None          0.5            dicod
# 3 2023-05-12 12:07:51.057000+00:00     None          0.5            dicod
# 4 2023-05-12 12:06:37.353000+00:00     None          0.5            dicod
#
#   tags.mlflow.source.type                            tags.mlflow.source.name  \
# 0                   LOCAL  C:\Users\dicod\anaconda3\lib\site-packages\ipy...
# 1                   LOCAL  C:\Users\dicod\anaconda3\lib\site-packages\ipy...
# 2                   LOCAL  C:\Users\dicod\anaconda3\lib\site-packages\ipy...
# 3                   LOCAL  C:\Users\dicod\anaconda3\lib\site-packages\ipy...
# 4                   LOCAL  C:\Users\dicod\anaconda3\lib\site-packages\ipy...
#
#   tags.mlflow.runName           tags.mlflow.parentRunId
# 0               run_1  6e0d24d6f1bf4567bfd09820c2c287ab
# 1               run_1  a535cabca57844349fce25846103e5df
# 2               run_1  05e2b6ae6f2041f2b31defb3ec7260a5
# 3               run_1  9c80ada3cde44b13b9d011309bb6cb37
# 4               run_1                              None

# %%
runs['artifact_uri'][0]
# Out:
# 'file:///C:/Users/dicod/semester_projects_02/mlruns/110241433576543131/6e0d24d6f1bf4567bfd09820c2c287ab/artifacts'

# %%
import mlflow.pyfunc

# Load the model from the registry
#"C:\Users\dicod\semester_projects_02\mlruns"
#semester_projects_02mlrunsmodels
# model_uri = '/content/model'

model_uri = "C:\\Users\\dicod\\semester_projects_02\\model"

loaded_model = mlflow.pyfunc.load_model(model_uri)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[70], line 10
#       3 # Load the model from the registry
#       4 #"C:\Users\dicod\semester_projects_02\mlruns"
#       5 #semester_projects_02mlrunsmodels
#       6 # model_uri = '/content/model'
#       8 model_uri = "C:\\Users\\dicod\\semester_projects_02\\model"
# ---> 10 loaded_model = mlflow.pyfunc.load_model(model_uri)
#
# File ~\anaconda3\lib\site-packages\mlflow\pyfunc\__init__.py:577, in load_model(model_uri, suppress_warnings, dst_path)
#     549 def load_model(
#     550     model_uri: str,
#     551     suppress_warnings: bool = False,
#     552     dst_path: str = None,
#     553 ) -> PyFuncModel:
#     554     """
#     555     Load a model stored in Python function format.
#     556
#    (...)
#     575                      path will be created.
#     576     """
# --> 577     local_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     579     if not suppress_warnings:
#     580         _warn_dependency_requirement_mismatches(local_path)
#
# File ~\anaconda3\lib\site-packages\mlflow\tracking\artifact_utils.py:100, in _download_artifact_from_uri(artifact_uri, output_path)
#      94 """
#      95 :param artifact_uri: The *absolute* URI of the artifact to download.
#      96 :param output_path: The local filesystem path to which to download the artifact. If unspecified,
#      97                     a local output path will be created.
#      98 """
#      99 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 100 return get_artifact_repository(artifact_uri=root_uri).download_artifacts(
#     101     artifact_path=artifact_path, dst_path=output_path
#     102 )
#
# File ~\anaconda3\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:106, in get_artifact_repository(artifact_uri)
#      96 def get_artifact_repository(artifact_uri):
#      97     """Get an artifact repository from the registry based on the scheme of artifact_uri
#      98
#      99     :param artifact_uri: The artifact store URI. This URI is used to select which artifact
#    (...)
#     104              requirements.
#     105     """
# --> 106     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File ~\anaconda3\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:66, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      64 repository = self._registry.get(scheme)
#      65 if repository is None:
# ---> 66     raise MlflowException(
#      67         "Could not find a registered artifact repository for: {}. "
#      68         "Currently registered schemes are: {}".format(
#      69             artifact_uri, list(self._registry.keys())
#      70         )
#      71     )
#      72 return repository(artifact_uri)
#
# MlflowException: Could not find a registered artifact repository for: c:. Currently registered schemes are: ['', 'file', 's3', 'gs', 'wasbs', 'ftp', 'sftp', 'dbfs', 'hdfs', 'viewfs', 'runs', 'models', 'http', 'https', 'mlflow-artifacts']
